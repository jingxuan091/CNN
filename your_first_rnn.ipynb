# %% [markdown]
# # Your first Recurrent Neural Network (RNN)

# %% [markdown]
# 🙌 Welcome to RNNs! After using CNNs in the previous lesson to deal with images (spatial data), you are going to deal with time-related data (***temporal data***).
#
# 🎯 Goals of this warm-up challenge:
# 1. Understand what temporal data is
# 2. Build your first Recurrent Neural Networks

# %% [markdown]
# ## A Note on Google Colab

# %% [markdown]
# From now on, you no longer need to use Google Colab. There will be **no performance gains** from using it, as today's machines are powerful enough to tackle this challenge — especially if you're on a MacBook with an MX chip! 😉
#
# Proceed with the challenge as you normally would with Jupyter Notebook (❌ Do not use Colab ❌)
#
# Good luck! 🚀

# %% [markdown]
# ## (1) 📚 The dataset

# %% [markdown]
# _Disclaimer: nothing to code by yourself in this section, read it carefully and run the cells. We want you to focus on the RNN and LSTM models, not some Pythonesque questions_ 😉

# %% [markdown]
# 🔢 Imagine that we have access to some data about employees in a company.

# %%
import numpy as np

X = np.load('X.npy')
y = np.load('y.npy')

# %%
X.shape, y.shape
# Out:
# ((25000, 10, 3), (25000,))

# %% [markdown]
# ☝️ The dataset describes the evolution of the **employment status of 25 000 employees, year after year**: each sequence corresponds to 10 consecutive years, where each year describes a job situation, comprising 3 components
# - the salary,
# - the number of people under someone's responsibility,
# - the size of the company.
#
# 🕵🏻 To understand the dataset a bit better, let's look at the data of the first employee.

# %%
import pandas as pd

employee_0 = pd.DataFrame(X[0],
                          columns=['salary',
                                   'responsibility',
                                   'company_size'])
round(employee_0,2)
# Out:
#    salary  responsibility  company_size
# 0    0.80           10.73         102.0
# 1    0.50           10.73         102.0
# 2    0.60           10.73         102.0
# 3    0.71           10.73         130.0
# 4    0.94           10.73         130.0
# 5    1.05           10.73         130.0
# 6    1.12           32.00         108.0
# 7    4.87           32.00         108.0
# 8    4.97           33.00         108.0
# 9    5.20           39.00         108.0

# %% [markdown]
# 🎯 The goal in this challenge is to predict the montly salary on the 11th year for each of these 25,000 employees, based on the past observations.

# %%
# For example, the first employee earns 6.499 k USD per month
# during the 11th year at the company
y[0]
# Out:
# 6.499

# %% [markdown]
# 📈 To help you get a better understanding about the evolution of the salaries, the number of people under their responsibility and the company size over the years, you can run the cell down below. Can you visually detect some correlations between these three variables?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

number_of_employees = len(X)

### Choosing random employees
##### As the employees are selected randomly, feel free to re-run this cell a few times !

number_of_randomly_selected_employees = 5

random_selection = np.random.randint(0, 
                                     number_of_employees,
                                     number_of_randomly_selected_employees)


### Plotting data for the selected employees

plt.title('Salary')
for r in random_selection:
    plt.plot(X[r, :, 0],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('# People responsibile for')
for r in random_selection:
    plt.plot(X[r, :, 1],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('Company sizes')
for r in random_selection:
    plt.plot(X[r, :, 2],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 🕵🏻 **Data Exploration** 🕵🏻 Look at the distribution of:
# * all the salaries during the 10th year,
# * people under someone's responsibility,
# * and the company sizes
#
# to get a better understanding of the variability of observations

# %%
import seaborn as sns

plt.title("Salaries on the 10th year")
sns.histplot(X[:, -1, 0].flatten()) # all the employees, last year, feature #0 = salaries
plt.show()

plt.title("# of people under someone's responsibility")
sns.histplot(X[:, :, 1].flatten()) # all the employees, all the years, feature #1 = responsabilities
plt.show()

plt.title("Company size")
sns.histplot(X[:, :, 2].flatten()) # all the employees, all the years, feature #2 = company size
plt.show()

# %% [markdown]
# ✂️ **Hold-out method** Let's split the dataset in a train and test set (80/20)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# Notice that we are train_test_splitting the 25 000 employees!

# %% [markdown]
# ## (2) 💻 A Simple RNN

# %% [markdown]
# 🤗 Now that you are familiar with this company's dataset, you will create your first Recurrent Neural Network. Let's start with a simple architecture.

# %% [markdown]
# ❓ **Question** ❓ Write a model that has:
# - a ***Normalization*** layer adapted to the training set
# - a ***SimpleRNN*** layer with 20 *units* (don't forget that `tanh` is better suited as an activation function for a Recurrent Layer)
# - a ***Dense*** layer with 10 neurons
# - a ***Dense*** layer specific to your task (= to ***predict*** a salary)
#
# 👩🏻‍🏫 <u>Remember</u>: You don't need to specify an `input_shape`: as soon as your Normalizer has been adapted to your train set, it has memorized the input shape!

# %%
from tensorflow.keras.layers import Normalization
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense, SimpleRNN, Flatten
from tensorflow.keras.optimizers import RMSprop

# %%
import numpy as np

y_train.shape
# Out:
# (20000,)

# %%
# YOUR CODE HERE

# 1- RNN Architecture
norm_layer = Normalization()
norm_layer.adapt(X_train)

model = Sequential()
model.add(norm_layer)
model.add(SimpleRNN(units=20, activation='tanh', input_shape=X_train.shape))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1, activation="linear"))



# 4- Predict
#model.predict(X)
# Out:
# 2023-03-09 10:58:49.013964: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %% [markdown]
# ❓ **Question**: How many trainable parameters does your RNN have ❓

# %%
# YOUR CODE HERE
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, None, 3)          7
#  n)
#
#  simple_rnn (SimpleRNN)      (None, 20)                480
#
#  dense (Dense)               (None, 10)                210
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 708
# Trainable params: 701
# Non-trainable params: 7
# _________________________________________________________________

# %% [markdown]
# ❓ **Question** ❓ Try to recompute the number of parameters manually.

# %% [markdown]
# > YOUR ANSWER HERE
#
# #Total params: 708
# #Trainable params: 701
# #Non-trainable params: 7

# %% [markdown]
# <details>
#     <summary><i>Answer</i></summary>
#
#
# - <u> Normalization Layer</u>:
#     - This layer has $\color{red}{n_x = 3} $ features (salary, responsibility, company size) to normalize. Each of them requires to compute the <font color=blue>_mean_</font>  and the <font color=blue>_standard_deviation_</font>. So we have $\color{red}{n_x = 3} \times \color{blue}{2} = 6$ non-trainable parameters. The 7th parameter is a bias initially set to 0.
#
# - <u> Recurrent Layer</u>:
#     - If $\color{green}{n_h = 20} $ RNN units are applied in parallel to $\color{red}{n_x = 3} $ features, then the Recurrent Layer has $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1) = \color{green}{20} \times (\color{green}{20}+\color{red}{3}+1) = \color{green}{20} \times 24 = 480$ parameters to train.
#     - Notice how this number is *independent* of the length of each sequence (here 10 days)
#
# - <u> Dense Layer</u>:
#     - Starting with $\color{green}{n_h = 20} $ RNN units and $1$ bias, using 10 neurons, the Dense Layer has $ (\color{green}{20}+1) \times 10 = 21 \times 10 = 210$ parameters
#
# - <u> Predictive Dense Layer</u>:
#     - Starting with $10$ neurons and $1$ bias, using 1 neuron to predict the 11th salary, the Predictive Dense Layer has $ (10+1) \times 1 = 11 \times 1 = 11$ parameters
#
# </details>

# %% [markdown]
# ❓ **Question** ❓ Compile your model. For RNN, we recommend you to use the ***rmsprop*** optimizer (instead of *adam*).

# %%
# YOUR CODE HERE
# Compilation
model.compile(loss='mae', 
              optimizer=RMSprop())

# %% [markdown]
# ❓ **Questions** ❓
#
# * Train your model on your training dataset:
#     * use a Validation Split of 20%
#     * and an Early Stopping Criterion with patience $= 5 $
# * Evaluate your performance on the test set

# %%
# YOUR CODE HERE
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience = 5)
model.fit(X_train, y_train, 
          epochs=100, 
          verbose=1,
          validation_split = 0.2,
          callbacks = [es],
          shuffle = True
         )
# Out:
# Epoch 1/100
# 500/500 [==============================] - 1s 907us/step - loss: 2.4193 - val_loss: 1.7284
# Epoch 2/100
# 500/500 [==============================] - 0s 685us/step - loss: 1.4336 - val_loss: 1.2207
# Epoch 3/100
# 500/500 [==============================] - 0s 725us/step - loss: 1.0725 - val_loss: 0.9777
# Epoch 4/100
# 500/500 [==============================] - 0s 680us/step - loss: 0.8941 - val_loss: 0.8937
# Epoch 5/100
# 500/500 [==============================] - 0s 682us/step - loss: 0.7878 - val_loss: 0.7910
# Epoch 6/100
# 500/500 [==============================] - 0s 686us/step - loss: 0.7163 - val_loss: 0.7284
# Epoch 7/100
# 500/500 [==============================] - 0s 690us/step - loss: 0.6632 - val_loss: 0.6667
# Epoch 8/100
# 500/500 [==============================] - 0s 685us/step - loss: 0.6228 - val_loss: 0.7172
# Epoch 9/100
# 500/500 [==============================] - 0s 685us/step - loss: 0.5913 - val_loss: 0.6130
# Epoch 10/100
# 500/500 [==============================] - 0s 685us/step - loss: 0.5664 - val_loss: 0.5731
# Epoch 11/100
# 500/500 [==============================] - 0s 689us/step - loss: 0.5468 - val_loss: 0.6024
# Epoch 12/100
# 500/500 [==============================] - 0s 688us/step - loss: 0.5291 - val_loss: 0.5353
# Epoch 13/100
# 500/500 [==============================] - 0s 681us/step - loss: 0.5144 - val_loss: 0.5327
# Epoch 14/100
# 500/500 [==============================] - 0s 689us/step - loss: 0.5013 - val_loss: 0.5041
# Epoch 15/100
# 500/500 [==============================] - 0s 733us/step - loss: 0.4892 - val_loss: 0.5342
# Epoch 16/100
# 500/500 [==============================] - 0s 726us/step - loss: 0.4813 - val_loss: 0.4964
# Epoch 17/100
# 500/500 [==============================] - 0s 684us/step - loss: 0.4717 - val_loss: 0.5715
# Epoch 18/100
# 500/500 [==============================] - 0s 699us/step - loss: 0.4634 - val_loss: 0.5067
# Epoch 19/100
# 500/500 [==============================] - 0s 709us/step - loss: 0.4546 - val_loss: 0.5078
# Epoch 20/100
# 500/500 [==============================] - 0s 678us/step - loss: 0.4493 - val_loss: 0.5038
# Epoch 21/100
# 500/500 [==============================] - 0s 680us/step - loss: 0.4435 - val_loss: 0.5127

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 0.46113377809524536

# %% [markdown]
# ## (3) 💻 Baseline comparison

# %% [markdown]
# > ❗️ **Important reminder** ❗️
# >
# > ***Always remember to compare your Deep Learning models, and more generally any Machine Learning model, to a baseline model.***
#
# 🧑🏻‍🏫 Remember that our goal is to predict the salary of the employees for the 11th year. It is a ***Regression task***. What baseline could we build?
# 1. In the case of a traditional regression model, a baseline prediction for `y_test` is  to **predict the average of `y_train`**... but this option could be irrelevant for time-related series. Theoretically, someone's salary is supposed to increase over the years!
# 2. An alternative baseline prediction for a regression task is to **predict the last seen value**

# %% [markdown]
# ❓ **Questions** ❓
# * Compute the Mean Absolute Error of a baseline model that predicts that the salary remains constant between the 10-th and 11-th year
# * Compare this baseline model to your RNN

# %%
# YOUR CODE HERE
def constant_prediction(X, y):
    errors = []
    for xx, yy in zip(X, y):
        last_salary = xx[-1][0]        # Using the 10th salary to predict the 11th salary
        errors.append(yy - last_salary)

    return errors

# %%
constant_prediction(X_test,y_test)
# Out:
# [0.0439999580383299,
#  0.14799997425079336,
#  0.05899953460693297,
#  0.11500002765655526,
#  0.10599995040893528,
#  0.10099995231628434,
#  0.1619998912811278,
#  0.030000064849853736,
#  0.5869998950958251,
#  0.16899983596801782,
#  0.18999998474121105,
#  1.5690000572204585,
#  0.25200009155273406,
#  0.08000004196166977,
#  0.1639999599456785,
#  3.00699967956543,
#  0.49700010681152307,
#  0.09700003719329842,
#  0.11900054931640724,
#  0.9749998931884765,
#  0.058000091552734556,
#  0.12099981307983398,
#  0.045000019073486275,
#  0.17599954986572186,
#  0.09000004959106445,
#  0.07999965667724673,
#  0.03300002098083499,
#  0.10700001907348611,
#  0.593000002861023,
#  0.16099988365173346,
#  0.11899991416931144,
#  0.18400000190734866,
#  3.083000032424927,
#  0.019000036239623874,
#  0.13899998474121134,
#  0.07000002861022947,
#  -0.08899997329711917,
#  -0.031000074386596577,
#  0.04299995803833001,
#  2.3470000133514404,
#  0.09800009155273415,
#  13.345999771118166,
#  0.10200011253356944,
#  0.14099991989135763,
#  0.0789999523162841,
#  0.05900001525878906,
#  0.19300011634826664,
#  0.21600006484985368,
#  0.02499991035461413,
#  0.09000004577636722,
#  0.07000004768371593,
#  0.15000000000000002,
#  0.9499999141693114,
#  0.15299999427795408,
#  0.10999988937377925,
#  0.10000000762939454,
#  0.45199998855590806,
#  0.061000473022460255,
#  -0.02800020599365194,
#  -1.3579999084472658,
#  0.08000002861022959,
#  11.134000152587891,
#  -0.009999990463256836,
#  0.14900001335144042,
#  0.07200009155273435,
#  -0.030999946594238104,
#  0.1410000686645505,
#  0.15300009155273386,
#  0.09100010681152337,
#  6.700000112533569,
#  0.11300002765655526,
#  0.033000108718872045,
#  1.0829999809265134,
#  1.6409997177124023,
#  0.08899998283386212,
#  0.13699998092651366,
#  0.17100012207031234,
#  0.05400003814697274,
#  2.182999975204468,
#  0.07499997711181638,
#  0.11099995708465582,
#  0.21600006484985368,
#  0.08899994468688965,
#  0.1030002365112308,
#  0.19299998855590816,
#  0.0729999885559085,
#  0.06599990081787066,
#  0.13100019836425858,
#  0.11499981689453165,
#  0.08000013732910194,
#  3.4109999752044677,
#  0.11900011253356935,
#  0.0,
#  0.10200003433227556,
#  0.11599999427795415,
#  0.05699993515014645,
#  -2.127999900817871,
#  0.19799991989135757,
#  0.06600003814697253,
#  0.16600004673004154,
#  0.12299997711181643,
#  0.14799976348876953,
#  0.9039999971389769,
#  0.08200022888183511,
#  -0.2609999980926512,
#  0.13299994945526117,
#  0.03999996471405032,
#  0.08300004959106433,
#  0.026000028610229542,
#  1.7809996795654293,
#  0.03400010299682599,
#  0.17900012969970724,
#  1.5799999370574955,
#  -3.156999824523926,
#  0.05000005626678461,
#  0.055000312805175255,
#  -0.49699995613098147,
#  0.041999987125396654,
#  0.08600005435943614,
#  1.8770000562667848,
#  0.10300012969970673,
#  0.11300004386901863,
#  0.142000051498413,
#  0.12400021362304692,
#  0.05200005626678461,
#  0.10400001144409199,
#  0.13400000667572032,
#  0.07900009536743147,
#  0.08599993133544936,
#  0.05499996376037597,
#  -0.004999908447265611,
#  0.11500003051757801,
#  0.46200000762939464,
#  -0.2549999694824221,
#  0.06899999809265145,
#  0.12499991989135761,
#  0.09999993133544915,
#  0.11200035095214922,
#  0.07400137329101852,
#  2.6330009460449233,
#  0.11500011825561529,
#  0.15799964141845635,
#  0.21300000762939497,
#  -0.026000083923339634,
#  0.49099992752075217,
#  0.16099963378906246,
#  0.9720000257492067,
#  0.6879999694824219,
#  0.06700007629394555,
#  -0.07200059509277423,
#  0.09900004291534414,
#  0.10400068664550943,
#  0.1079999866485597,
#  -0.14700004768371588,
#  0.08599997520446756,
#  0.3799999694824221,
#  8.139000137329102,
#  -0.12500025939941395,
#  -8.873999938964843,
#  0.10900001907348633,
#  0.0009999847412109908,
#  0.11600004863739022,
#  0.1500000209808352,
#  0.1579999494552613,
#  0.030000213623046612,
#  0.06099998092651404,
#  -0.027000194549560597,
#  0.6399999389648432,
#  0.9680001487731937,
#  0.14599977111816287,
#  0.172000054359436,
#  0.08300003433227543,
#  2.3390001373291014,
#  0.06500015258789027,
#  0.09299990463256824,
#  0.24900004482269278,
#  0.18899994850158697,
#  -0.12499997901916493,
#  0.15300004673004142,
#  0.15199996948242145,
#  0.9370000209808351,
#  0.08100015640258817,
#  -0.0030000686645506036,
#  0.18399990272521993,
#  0.21300002574920662,
#  0.0959999084472658,
#  -0.3609998703002928,
#  0.06200004863739017,
#  0.07600000190734857,
#  0.11599997425079356,
#  0.14799995803833,
#  0.062000089645385614,
#  0.40800004196167006,
#  0.11199999999999999,
#  0.13399998188018802,
#  0.15499995422363266,
#  0.11600003051757835,
#  -0.01900004577636727,
#  0.010000007629393792,
#  -0.159999771118164,
#  0.102000038146973,
#  0.11300009918212872,
#  0.06700003433227542,
#  5.499000457763671,
#  0.15399989700317374,
#  0.09399999999999997,
#  0.12599988555908181,
#  -1.3839999179840088,
#  1.2240000686645507,
#  0.1280000762939455,
#  -0.2070002174377441,
#  0.061999933242797844,
#  0.8970000724792477,
#  -2.151999649047852,
#  0.05099994659423834,
#  0.13700005722045905,
#  0.13600010871887225,
#  0.07200000572204601,
#  0.18499994468688952,
#  0.8240000505447389,
#  -0.09099981689453163,
#  2.732999991416931,
#  0.1320000295639039,
#  -1.3959998989105225,
#  0.03999998092651369,
#  -1.4820003662109373,
#  0.055999885559081974,
#  1.0819999542236332,
#  0.07399994659423825,
#  0.07500033569335862,
#  0.12800004386901875,
#  0.07299994277954092,
#  0.10099956512451236,
#  0.09299996376037578,
#  0.10500002098083483,
#  0.10100011634826656,
#  6.206000183105468,
#  0.12800002765655516,
#  -4.695999755859375,
#  0.3260001182556156,
#  0.14800005722045917,
#  ...]

# %% [markdown]
# 👉 If you are stuck with this question, try `(4) LSTM` and come back to this afterwards.
#
# 🧑🏻‍🏫 Ask a TA if needed. Look at the answer only if you already tried to answer these questions unsuccessfully.
#
# <details>
#     <summary><i>Answer</i></summary>
#
#
# ```python
# def constant_prediction(X, y):
#     errors = []
#     for xx, yy in zip(X, y):
#         last_salary = xx[-1][0]        # Using the 10th salary to predict the 11th salary
#         errors.append(yy - last_salary)
#
#     return errors
# ```
#
# </details>

# %% [markdown]
# 😁 You should notice that your RNN performs a bit better than a baseline model.

# %% [markdown]
# ## (4) 💻 LSTM: Long-Short Term Memory

# %% [markdown]
# ❓ **Questions** ❓
#
# * Write the exact same model, but with a `LSTM` layer instead of a `SimpleRNN` layer
# * Evaluate your performance on the test set

# %%
# YOUR CODE HERE
from tensorflow.keras.layers import LSTM
model = Sequential()
model.add(norm_layer)
model.add(LSTM(units=20, activation='tanh', input_shape=X_train.shape))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1, activation="linear"))

# %%
model.compile(loss='mae', 
              optimizer=RMSprop())

# %%
es = EarlyStopping(patience = 5)
model.fit(X_train, y_train, 
          epochs=100, 
          verbose=1,
          validation_split = 0.2,
          callbacks = [es],
          shuffle = True
         )
# Out:
# Epoch 1/100
# 500/500 [==============================] - 2s 2ms/step - loss: 2.2953 - val_loss: 1.6469
# Epoch 2/100
# 500/500 [==============================] - 1s 1ms/step - loss: 1.3002 - val_loss: 1.1301
# Epoch 3/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9264 - val_loss: 0.8616
# Epoch 4/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7582 - val_loss: 0.7426
# Epoch 5/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6710 - val_loss: 0.6550
# Epoch 6/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6122 - val_loss: 0.6865
# Epoch 7/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.5703 - val_loss: 0.5728
# Epoch 8/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.5377 - val_loss: 0.5614
# Epoch 9/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.5125 - val_loss: 0.5294
# Epoch 10/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4936 - val_loss: 0.5259
# Epoch 11/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4759 - val_loss: 0.4949
# Epoch 12/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4622 - val_loss: 0.4911
# Epoch 13/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4500 - val_loss: 0.4821
# Epoch 14/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4386 - val_loss: 0.4951
# Epoch 15/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4299 - val_loss: 0.4576
# Epoch 16/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4201 - val_loss: 0.4778
# Epoch 17/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4122 - val_loss: 0.4231
# Epoch 18/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4060 - val_loss: 0.4701
# Epoch 19/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3995 - val_loss: 0.4356
# Epoch 20/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3942 - val_loss: 0.4362
# Epoch 21/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3883 - val_loss: 0.4010
# Epoch 22/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3821 - val_loss: 0.4067
# Epoch 23/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3774 - val_loss: 0.3967
# Epoch 24/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3724 - val_loss: 0.4168
# Epoch 25/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3691 - val_loss: 0.3772
# Epoch 26/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3639 - val_loss: 0.3726
# Epoch 27/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3613 - val_loss: 0.3987
# Epoch 28/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3564 - val_loss: 0.3722
# Epoch 29/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3530 - val_loss: 0.3574
# Epoch 30/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3495 - val_loss: 0.3566
# Epoch 31/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3475 - val_loss: 0.3743
# Epoch 32/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3440 - val_loss: 0.3645
# Epoch 33/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3416 - val_loss: 0.3616
# Epoch 34/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3393 - val_loss: 0.3448
# Epoch 35/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3366 - val_loss: 0.3505
# Epoch 36/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3333 - val_loss: 0.3474
# Epoch 37/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3321 - val_loss: 0.3380
# Epoch 38/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3305 - val_loss: 0.3536
# Epoch 39/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3276 - val_loss: 0.3392
# Epoch 40/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3261 - val_loss: 0.3712
# Epoch 41/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3233 - val_loss: 0.3890
# Epoch 42/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3215 - val_loss: 0.3476

# %% [markdown]
# 💪 The LSTM should perform a bit better than the SimpleRNN with a lower MAE.

# %% [markdown]
# 🏁 Congratulations! You know how to train a RNN on sequential data.
#
#
# 💾 Do not forget to git add/commit/push your notebook...
#
# 🚀 ... and move to the next challenge!
#
# ---
#
# <u>Note</u>: The sequences you worked with are totally fake. In case, you need to train and reproduce similar data, you can find below the functions that have been used to simulate such a dataset.

# %% [markdown]
# ## 🛠 (Utils)

# %%
def create_sequences(number):
    X, y = [], []
    
    for i in range(number):
        x_i, y_i = create_individual_sequence(10)
        X.append(x_i)
        y.append(y_i)
        
    return np.array(X), np.array(y)
            
def create_individual_sequence(length):
    company_sizes = []
    nb_persons = []
    salaries = []
    
    
    # Education level
    educ_level = [max(0, int(np.random.normal(10, 2)))]*length
    
    # Company size
    current_size = int(1 + np.random.beta(.4, 4)*500)
    for i in range(length):
        if not np.random.randint(4): # Change 1 out of 3 possibilities 
            current_size = int(max(1, np.random.normal(current_size, 50)))
        company_sizes.append(current_size)
    
    # Number of persons
    nb_iter = np.random.beta(.15, 4)*300
    for i in range(length):
        if not np.random.randint(2): # Change 1 out of 2 possibilities
            R_1 = np.random.beta(0.5, 8)*3
            nb_iter = nb_iter + max(-2, R_1*company_sizes[i] + np.random.randint(-2, 2))
            nb_iter = max(0, nb_iter)
            nb_iter = int(min(company_sizes[i]-1, nb_iter))
        nb_persons.append(nb_iter)
        
    
    # Salary
    salary_iter = max(800, int(np.random.normal(1200, 300)+ 0.05*company_sizes[0] +  np.random.normal(40, 400)))
    salaries.append(salary_iter)
    for i in range(1, length + 1):
        R_1 = np.random.normal(100, 50)
        change_person = nb_persons[i-1] - nb_persons[i-2]
        change_company = max(0, company_sizes[i-1] - company_sizes[i-2])
        salary_iter = salary_iter + 0.05*change_company + change_person*R_1 + np.random.normal(100, 50)
        salary_iter = max(int(salary_iter), 500)
        
        salaries.append(salary_iter)

    y = salaries[-1]/1000
    salaries = [_/1000 for _ in salaries[:-1]]
    
    return np.array([salaries, nb_persons, company_sizes]).T, y

# %%
X, y = create_sequences(25000)

np.save('X', X.astype(np.float32))
np.save('y', y)
