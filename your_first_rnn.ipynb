# %% [markdown]
# # Your first Recurrent Neural Network (RNN)

# %% [markdown]
# 🙌 Welcome to RNNs! After using CNNs in the previous lesson to deal with images (spatial data), you are going to deal with time-related data (***temporal data***).
#
# 🎯 Goals of this warm-up challenge:
# 1. Understand what temporal data is
# 2. Build your first Recurrent Neural Networks

# %% [markdown]
# ## A Note on Google Colab

# %% [markdown]
# From now on, you no longer need to use Google Colab. There will be **no performance gains** from using it, as today's machines are powerful enough to tackle this challenge — especially if you're on a MacBook with an MX chip! 😉
#
# Proceed with the challenge as you normally would with Jupyter Notebook (❌ Do not use Colab ❌)
#
# Good luck! 🚀

# %% [markdown]
# ## (1) 📚 The dataset

# %% [markdown]
# _Disclaimer: nothing to code by yourself in this section, read it carefully and run the cells. We want you to focus on the RNN and LSTM models, not some Pythonesque questions_ 😉

# %% [markdown]
# 🔢 Imagine that we have access to some data about employees in a company.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense, SimpleRNN, Flatten, Normalization, LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %%
X = np.load('X.npy')
y = np.load('y.npy')

# %% [markdown]
# ☝️ The dataset describes the evolution of the **employment status of 25 000 employees, year after year**: each sequence corresponds to 10 consecutive years, where each year describes a job situation, comprising 3 components
# - the salary,
# - the number of people under someone's responsibility,
# - the size of the company.
#
# 🕵🏻 To understand the dataset a bit better, let's look at the data of the first employee.

# %%
employee_0 = pd.DataFrame(X[0],
                          columns=['salary',
                                   'responsibility',
                                   'company_size'])
round(employee_0,2)
# Out:
#    salary  responsibility  company_size
# 0    0.80             2.0           6.0
# 1    1.18             2.0           6.0
# 2    1.32             2.0           6.0
# 3    1.48             0.0           6.0
# 4    1.44             0.0           6.0
# 5    1.48             0.0           6.0
# 6    1.59             0.0           1.0
# 7    1.64             0.0           1.0
# 8    1.79             0.0           1.0
# 9    1.90             0.0           1.0

# %% [markdown]
# 🎯 The goal in this challenge is to predict the montly salary on the 11th year for each of these 25,000 employees, based on the past observations.

# %% [markdown]
# 📈 To help you get a better understanding about the evolution of the salaries, the number of people under their responsibility and the company size over the years, you can run the cell down below. Can you visually detect some correlations between these three variables?

# %%
# %matplotlib inline

number_of_employees = len(X)

### Choosing random employees
##### As the employees are selected randomly, feel free to re-run this cell a few times !

number_of_randomly_selected_employees = 5

random_selection = np.random.randint(0, 
                                     number_of_employees,
                                     number_of_randomly_selected_employees)


### Plotting data for the selected employees

plt.title('Salary')
for r in random_selection:
    plt.plot(X[r, :, 0],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('# People responsibile for')
for r in random_selection:
    plt.plot(X[r, :, 1],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('Company sizes')
for r in random_selection:
    plt.plot(X[r, :, 2],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 🕵🏻 **Data Exploration** 🕵🏻 Look at the distribution of:
# * all the salaries during the 10th year,
# * people under someone's responsibility,
# * and the company sizes
#
# to get a better understanding of the variability of observations

# %%
plt.title("Salaries on the 10th year")
sns.histplot(X[:, -1, 0].flatten()) # all the employees, last year, feature #0 = salaries
plt.show()

plt.title("# of people under someone's responsibility")
sns.histplot(X[:, :, 1].flatten()) # all the employees, all the years, feature #1 = responsabilities
plt.show()

plt.title("Company size")
sns.histplot(X[:, :, 2].flatten()) # all the employees, all the years, feature #2 = company size
plt.show()

# %% [markdown]
# ✂️ **Hold-out method** Let's split the dataset in a train and test set (80/20)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# ## (2) 💻 A Simple RNN

# %% [markdown]
# 🤗 Now that you are familiar with this company's dataset, you will create your first Recurrent Neural Network. Let's start with a simple architecture.

# %% [markdown]
# ❓ **Question** ❓ Write a model that has:
# - a ***Normalization*** layer adapted to the training set
# - a ***SimpleRNN*** layer with 20 *units* (don't forget that `tanh` is better suited as an activation function for a Recurrent Layer)
# - a ***Dense*** layer with 10 neurons
# - a ***Dense*** layer specific to your task (= to ***predict*** a salary)
#
# 👩🏻‍🏫 <u>Remember</u>: You don't need to specify an `input_shape`: as soon as your Normalizer has been adapted to your train set, it has memorized the input shape!

# %%
# YOUR CODE HERE

# 1- RNN Architecture
norm_layer = Normalization()
norm_layer.adapt(X_train)

model = Sequential()
model.add(norm_layer)
model.add(SimpleRNN(units=20, activation='tanh', input_shape=X_train.shape))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1, activation="linear"))
# Out:
# 2023-04-05 14:03:29.550214: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %% [markdown]
# ❓ **Question**: How many trainable parameters does your RNN have ❓

# %%
# YOUR CODE HERE
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, None, 3)          7
#  n)
#
#  simple_rnn (SimpleRNN)      (None, 20)                480
#
#  dense (Dense)               (None, 10)                210
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 708
# Trainable params: 701
# Non-trainable params: 7
# _________________________________________________________________

# %% [markdown]
# ❓ **Question** ❓ Try to recompute the number of parameters manually.

# %% [markdown]
# > YOUR ANSWER HERE
#
# #Total params: 708
# #Trainable params: 701
# #Non-trainable params: 7

# %% [markdown]
# <details>
#     <summary><i>Answer</i></summary>
#
#
# - <u> Normalization Layer</u>:
#     - This layer has $\color{red}{n_x = 3} $ features (salary, responsibility, company size) to normalize. Each of them requires to compute the <font color=blue>_mean_</font>  and the <font color=blue>_standard_deviation_</font>. So we have $\color{red}{n_x = 3} \times \color{blue}{2} = 6$ non-trainable parameters. The 7th parameter is a bias initially set to 0.
#
# - <u> Recurrent Layer</u>:
#     - If $\color{green}{n_h = 20} $ RNN units are applied in parallel to $\color{red}{n_x = 3} $ features, then the Recurrent Layer has $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1) = \color{green}{20} \times (\color{green}{20}+\color{red}{3}+1) = \color{green}{20} \times 24 = 480$ parameters to train.
#     - Notice how this number is *independent* of the length of each sequence (here 10 days)
#
# - <u> Dense Layer</u>:
#     - Starting with $\color{green}{n_h = 20} $ RNN units and $1$ bias, using 10 neurons, the Dense Layer has $ (\color{green}{20}+1) \times 10 = 21 \times 10 = 210$ parameters
#
# - <u> Predictive Dense Layer</u>:
#     - Starting with $10$ neurons and $1$ bias, using 1 neuron to predict the 11th salary, the Predictive Dense Layer has $ (10+1) \times 1 = 11 \times 1 = 11$ parameters
#
# </details>

# %% [markdown]
# ❓ **Question** ❓ Compile your model. For RNN, we recommend you to use the ***rmsprop*** optimizer (instead of *adam*).

# %%
# YOUR CODE HERE
# Compilation
model.compile(loss='mae', 
              optimizer=RMSprop())

# %% [markdown]
# ❓ **Questions** ❓
#
# * Train your model on your training dataset:
#     * use a Validation Split of 20%
#     * and an Early Stopping Criterion with patience $= 5 $
# * Evaluate your performance on the test set

# %%
# YOUR CODE HERE
es = EarlyStopping(patience = 5)
model.fit(X_train, y_train, 
          epochs=100, 
          verbose=1,
          validation_split = 0.2,
          callbacks = [es],
          shuffle = True
         )
# Out:
# Epoch 1/100
# 500/500 [==============================] - 1s 1ms/step - loss: 2.2144 - val_loss: 1.5817
# Epoch 2/100
# 500/500 [==============================] - 0s 803us/step - loss: 1.3456 - val_loss: 1.1700
# Epoch 3/100
# 500/500 [==============================] - 0s 810us/step - loss: 1.0273 - val_loss: 0.9674
# Epoch 4/100
# 500/500 [==============================] - 0s 802us/step - loss: 0.8582 - val_loss: 0.8821
# Epoch 5/100
# 500/500 [==============================] - 0s 802us/step - loss: 0.7650 - val_loss: 0.7589
# Epoch 6/100
# 500/500 [==============================] - 0s 848us/step - loss: 0.7025 - val_loss: 0.6813
# Epoch 7/100
# 500/500 [==============================] - 0s 798us/step - loss: 0.6566 - val_loss: 0.6331
# Epoch 8/100
# 500/500 [==============================] - 0s 805us/step - loss: 0.6196 - val_loss: 0.5642
# Epoch 9/100
# 500/500 [==============================] - 0s 795us/step - loss: 0.5925 - val_loss: 0.5573
# Epoch 10/100
# 500/500 [==============================] - 0s 804us/step - loss: 0.5674 - val_loss: 0.5268
# Epoch 11/100
# 500/500 [==============================] - 0s 818us/step - loss: 0.5480 - val_loss: 0.5597
# Epoch 12/100
# 500/500 [==============================] - 0s 827us/step - loss: 0.5329 - val_loss: 0.5163
# Epoch 13/100
# 500/500 [==============================] - 0s 793us/step - loss: 0.5160 - val_loss: 0.4862
# Epoch 14/100
# 500/500 [==============================] - 0s 806us/step - loss: 0.5039 - val_loss: 0.4897
# Epoch 15/100
# 500/500 [==============================] - 0s 809us/step - loss: 0.4917 - val_loss: 0.5067
# Epoch 16/100
# 500/500 [==============================] - 0s 856us/step - loss: 0.4807 - val_loss: 0.4802
# Epoch 17/100
# 500/500 [==============================] - 0s 810us/step - loss: 0.4712 - val_loss: 0.4810
# Epoch 18/100
# 500/500 [==============================] - 0s 772us/step - loss: 0.4628 - val_loss: 0.4427
# Epoch 19/100
# 500/500 [==============================] - 0s 777us/step - loss: 0.4554 - val_loss: 0.4385
# Epoch 20/100
# 500/500 [==============================] - 0s 789us/step - loss: 0.4476 - val_loss: 0.4182
# Epoch 21/100
# 500/500 [==============================] - 0s 777us/step - loss: 0.4417 - val_loss: 0.4379
# Epoch 22/100
# 500/500 [==============================] - 0s 799us/step - loss: 0.4350 - val_loss: 0.4495
# Epoch 23/100
# 500/500 [==============================] - 0s 824us/step - loss: 0.4291 - val_loss: 0.4495
# Epoch 24/100
# 500/500 [==============================] - 0s 788us/step - loss: 0.4235 - val_loss: 0.4070
# Epoch 25/100
# 500/500 [==============================] - 0s 798us/step - loss: 0.4180 - val_loss: 0.3862
# Epoch 26/100
# 500/500 [==============================] - 0s 811us/step - loss: 0.4136 - val_loss: 0.4222
# Epoch 27/100
# 500/500 [==============================] - 0s 778us/step - loss: 0.4078 - val_loss: 0.4204
# Epoch 28/100
# 500/500 [==============================] - 0s 799us/step - loss: 0.4032 - val_loss: 0.3789
# Epoch 29/100
# 500/500 [==============================] - 0s 779us/step - loss: 0.3991 - val_loss: 0.4232
# Epoch 30/100
# 500/500 [==============================] - 0s 807us/step - loss: 0.3949 - val_loss: 0.3797
# Epoch 31/100
# 500/500 [==============================] - 0s 773us/step - loss: 0.3910 - val_loss: 0.3853
# Epoch 32/100
# 500/500 [==============================] - 0s 778us/step - loss: 0.3879 - val_loss: 0.4197
# Epoch 33/100
# 500/500 [==============================] - 0s 780us/step - loss: 0.3834 - val_loss: 0.3871

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# 0.40309035778045654

# %% [markdown]
# ## (3) 💻 Baseline comparison

# %% [markdown]
# > ❗️ **Important reminder** ❗️
# >
# > ***Always remember to compare your Deep Learning models, and more generally any Machine Learning model, to a baseline model.***
#
# 🧑🏻‍🏫 Remember that our goal is to predict the salary of the employees for the 11th year. It is a ***Regression task***. What baseline could we build?
# 1. In the case of a traditional regression model, a baseline prediction for `y_test` is  to **predict the average of `y_train`**... but this option could be irrelevant for time-related series. Theoretically, someone's salary is supposed to increase over the years!
# 2. An alternative baseline prediction for a regression task is to **predict the last seen value**

# %% [markdown]
# ❓ **Questions** ❓
# * Compute the Mean Absolute Error of a baseline model that predicts that the salary remains constant between the 10-th and 11-th year
# * Compare this baseline model to your RNN

# %%
# YOUR CODE HERE
def constant_prediction(X, y):
    errors = []
    for xx, yy in zip(X, y):
        last_salary = xx[-1][0]        # Using the 10th salary to predict the 11th salary
        errors.append(yy - last_salary)

    return errors

#  -0.32199989318847644,
#  0.14099983978271524,
#  0.02199999237060557,
#  0.1670000915527341,
#  0.006000000000000005,
#  0.04900002670288117,
#  0.2469999618530272,
#  -0.05800008201599116,
#  0.34600026702880804,
#  0.2069997901916505,
#  0.07300023269653355,
#  1.4220000076293946,
#  0.054999805450439254,
#  0.053999902725219595,
#  0.14299999427795407,
#  0.15999995708465575,
#  0.07100008773803701,
#  0.13000003242492664,
#  1.0729999580383303,
#  0.11499992942810078,
#  0.15099991226196297,
#  0.08400005054473869,
#  0.03699995803833023,
#  0.03999988937377896,
#  0.09599990653991686,
#  0.18199992370605456,
#  0.09599999809265136,
#  0.04400001525878894,
#  0.5229999408721926,
#  0.06900000190734845,
#  0.16999997711181658,
#  0.05300000286102291,
#  0.14599992752075197,
#  0.11499997043609622,
#  0.15900005722045885,
#  0.3100000114440915,
#  0.061000072479248324,
#  0.04000003147125253,
#  0.09499998426437384,
#  1.0150001754760734,
#  1.886000396728516,
#  4.781000022888184,
#  0.14300003623962398,
#  -0.3800000581741333,
#  0.14299986648559582,
#  0.062000190734863736,
#  0.08699991416931141,
#  0.385998992919923,
#  0.07500000476837165,
#  0.07300000143051144,
#  0.07199999237060517,
#  0.013000236511230057,
#  -0.13299991035461423,
#  0.057000068664550874,
#  3.226,
#  0.15799992561340348,
#  3.3290000228881844,
#  0.14000003433227537,
#  0.19299994468688952,
#  0.28699999046325697,
#  0.07600010490417475,
#  8.993000427246095,
#  -0.8619999923706056,
#  0.11200009918212883,
#  0.9670000314712524,
#  0.11199995613098146,
#  0.03300011825561544,
#  0.039000000000000035,
#  1.7399999904632568,
#  -0.7549999351501464,
#  0.10599977111816372,
#  0.19600045013427803,
#  0.018999980926513782,
#  0.03300002861022966,
#  0.10700014114379908,
#  0.15400003051757816,
#  0.11799974822998038,
#  0.027000023841857956,
#  -0.04899997711181636,
#  0.12299986648559535,
#  0.17300001144409194,
#  0.12099988555908237,
#  0.089000027179718,
#  0.1649999027252198,
#  0.11900004959106436,
#  0.25899996948242254,
#  2.1719998893737795,
#  0.1109998207092282,
#  -1.9750006561279285,
#  0.15599992179870625,
#  0.007000082015991005,
#  0.20000003242492692,
#  3.5290000152587897,
#  -0.7860000476837159,
#  0.1180001640319821,
#  1.9189999256134032,
#  0.15900001859664914,
#  1.3370000162124636,
#  0.5470000610351562,
#  -0.996000020980835,
#  0.033000057220458956,
#  0.06600001144409173,
#  1.7230000295639036,
#  0.029999984741210906,
#  0.08899997711181662,
#  0.08100008773803724,
#  -0.07399931335449139,
#  0.05599984741211017,
#  0.058000114440917905,
#  1.9529999675750735,
#  -4.051999771118164,
#  0.05699987030029341,
#  0.26399996566772455,
#  0.1710000610351563,
#  0.03800000381469726,
#  0.04599998569488517,
#  0.24499988174438458,
#  0.1129999465942384,
#  0.1100001182556154,
#  0.11600010299682628,
#  0.17999995231628407,
#  0.09500004196166989,
#  -0.16699997329711902,
#  6.44899994277954,
#  0.0010000801086427202,
#  0.09900002288818355,
#  0.12799948120117222,
#  0.09000012969970683,
#  0.1419999732971191,
#  0.07299988555908232,
#  0.12700006294250477,
#  0.07800000953674324,
#  0.0790000138282776,
#  0.13200005245208746,
#  0.10099997711181641,
#  0.07899998664855956,
#  5.107000055313111,
#  0.05100005054473877,
#  0.0060001525878909945,
#  0.04599993324279783,
#  1.5499999885559088,
#  0.11999995040893552,
#  0.07200003433227531,
#  0.132000082015991,
#  0.24399992370605483,
#  0.10800008392333993,
#  -0.04599965667724604,
#  0.08099995994567877,
#  0.04400006103515608,
#  0.07699999332427976,
#  0.1049991149902354,
#  0.06299995613098153,
#  -0.14399998474121123,
#  0.24599989318847637,
#  0.29300000190734865,
#  0.0789999456405639,
#  1.4090000228881836,
#  0.03799993896484377,
#  0.03499999904632567,
#  3.4629999351501466,
#  1.6519998397827145,
#  0.0830000324249267,
#  0.09199990653991685,
#  0.10099999809265148,
#  -1.7760001449584961,
#  0.02499995613098127,
#  0.1630000162124634,
#  0.11600000476837158,
#  -0.3880000467300415,
#  0.11599999141693118,
#  0.15399987792968783,
#  0.11799996852874761,
#  0.2850000896453859,
#  0.1060003967285148,
#  0.12500000190734895,
#  0.16800035095214838,
#  -0.00600009155273451,
#  5.517000012397766,
#  9.022999910354613,
#  0.15300004959106417,
#  0.42599995422363257,
#  0.0689999856948853,
#  0.09000003337860107,
#  0.11600003433227535,
#  0.045999958038330124,
#  0.2539999804496764,
#  0.11000006294250486,
#  0.04100001144409138,
#  0.11499992370605483,
#  1.2270000400543215,
#  0.1230000181198121,
#  0.05499986648559574,
#  1.9230000610351565,
#  0.012000108718872138,
#  6.772000167846679,
#  0.09499988365173362,
#  -0.037000228881835184,
#  0.1460000877380372,
#  0.09599992370605293,
#  0.09400000572204581,
#  0.1850000610351561,
#  0.8159999961853028,
#  0.16899988555908196,
#  0.5830000896453855,
#  -5.490000049591064,
#  0.1440001049041748,
#  0.22400004577636712,
#  0.12200001525878901,
#  0.11699991226196271,
#  0.055000019073486506,
#  0.14799997520446784,
#  0.0010000667572023225,
#  0.12599993896484385,
#  -0.07500004577636732,
#  0.1639999732971189,
#  0.03300012969970734,
#  0.08700008201599108,
#  2.352000152587891,
#  0.019999910354614236,
#  0.012999933242797912,
#  0.051999797821045135,
#  0.31900001144409185,
#  0.12999995040893575,
#  0.14999993324279792,
#  0.18500030517578203,
#  -0.17400001335144033,
#  0.1129999485015869,
#  0.15299996280670158,
#  0.4889997406005868,
#  0.04400009918212877,
#  0.14699997711181645,
#  0.11799998092651354,
#  0.06899997711181638,
#  1.1470000534057618,
#  -0.169000005722046,
#  0.027999956130981385,
#  0.1119999599456789,
#  -0.3099998874664305,
#  3.1199999914169307,
#  0.11400004959106447,
#  1.0919999942779537,
#  0.11700002479553229,
#  0.0780000057220458,
#  0.07600001335144047,
#  0.05400004577636719,
#  0.08700003051757799,
#  -0.18100004863739017,
#  0.053000093460083164,
#  0.06900003814697264,
#  0.07500173950194977,
#  0.15200006484985362,
#  0.43299995994567864,
#  0.01599997711181622,
#  0.15399995708465575,
#  1.0410000209808348,
#  0.069000251770019,
#  0.18999995517730728,
#  0.15099990081787062,
#  0.06299980163574048,
#  0.14399988555908205,
#  0.09299998950958255,
#  0.16899987792968751,
#  0.08299984741210942,
#  0.10299995708465559,
#  3.398999883651733,
#  0.09799999999999986,
#  0.13500005340576182,
#  0.12699997520446793,
#  0.18600002861022946,
#  0.10499990463256825,
#  -1.0539999389648438,
#  0.3010000228881835,
#  6.390000002861022,
#  0.16200020980834928,
#  -0.6649999675750733,
#  -0.4880000972747802,
#  0.15799998378753655,
#  -0.12100000762939445,
#  2.1510001220703128,
#  0.0539999084472651,
#  0.14400006675720212,
#  0.3439999885559084,
#  0.11499988746643064,
#  1.5160000228881838,
#  0.09300002670288077,
#  0.12800008773803695,
#  0.024999877929687386,
#  -0.021000013351440527,
#  0.074000244140624,
#  22.603000450134278,
#  15.133000076293946,
#  0.05699996852874767,
#  0.12099991989135761,
#  0.17100000190734876,
#  0.08499997329711917,
#  -0.012000055313110325,
#  0.05199995708465566,
#  0.04399982452392592,
#  0.1109999618530273,
#  0.1600000581741332,
#  0.5820000648498533,
#  0.06899990272521972,
#  5.6419998703002925,
#  0.025999979019164954,
#  -0.07399996280670162,
#  0.12299989891052254,
#  0.6570000247955323,
#  0.007999998092651284,
#  0.05699989891052226,
#  0.039999954223632894,
#  0.13000071716308526,
#  -0.6460000276565552,
#  0.14500001335144042,
#  2.349000274658204,
#  0.23100018310546844,
#  -0.07000004386901848,
#  5.642000001907348,
#  -7.09499979019165,
#  23.39800079345703,
#  0.2059999618530277,
#  0.18199998188018807,
#  0.09899909973144361,
#  0.9629999008178718,
#  0.08299995803833005,
#  0.06899905395507844,
#  0.0029999694824218714,
#  0.11600017166137722,
#  0.10399989700317391,
#  -6.892000198364258,
#  0.0640000190734864,
#  0.050000007629394716,
#  0.14199999713897715,
#  0.008000045776367148,
#  0.12099992752075206,
#  2.2400002174377445,
#  0.15499989128112812,
#  0.24600013351440442,
#  0.13800012207031287,
#  0.23099994468688978,
#  6.744000228881838,
#  0.017999970436096246,
#  0.07700011062622103,
#  1.0600000820159914,
#  0.0919998970031739,
#  0.7739999742507935,
#  -0.04100010681152355,
#  0.1169999694824213,
#  0.05799995231628419,
#  0.10999991798400899,
#  15.134000381469725,
#  0.01000002288818358,
#  -0.12300003814697269,
#  0.6829998626708988,
#  0.023000225067138835,
#  4.380999870300293,
#  0.11899969482421824,
#  0.06800000667572004,
#  0.11300004005432118,
#  0.3459999370574951,
#  0.06799999237060561,
#  0.032000019073486374,
#  4.8809999580383305,
#  0.03799993133544888,
#  0.00799998760223386,
#  0.6719999656677245,
#  0.09000061035156293,
#  0.12699994754791266,
#  3.3550001106262215,
#  0.07100004196167031,
#  0.14000011253356925,
#  0.048000089645385824,
#  0.09799989128112774,
#  0.13699998569488536,
#  2.655999938964844,
#  6.306000034332276,
#  0.14199991226196307,
#  0.13300000190734873,
#  0.14699992370605486,
#  0.09500011444091783,
#  -0.16100000762939448,
#  0.14600023651123006,
#  0.0980000505447387,
#  0.06600007820129417,
#  0.16199996948242212,
#  0.06299983596801795,
#  0.1979999351501469,
#  1.0879998397827144,
#  0.0610001869201664,
#  0.10099995040893561,
#  0.05500011825561524,
#  0.045000236511230085,
#  0.10799962615966763,
#  0.08400003242492682,
#  0.16700012207031278,
#  6.794999980926514,
#  0.27599996185302755,
#  -9.133000373840332,
#  0.09000011253356943,
#  0.11599954986572314,
#  -0.1100001106262205,
#  0.6699999780654906,
#  0.10300037384033267,
#  0.022000093460083026,
#  6.033000335693359,
#  0.1699999542236328,
#  3.516999938964844,
#  0.09200032806396408,
#  0.1899999561309813,
#  6.875999947547912,
#  5.221999965667724,
#  -0.01999988937377939,
#  0.08500006675720195,
#  0.1930000157356262,
#  1.7819999465942384,
#  0.05200003814697274,
#  0.04400007438659648,
#  0.11399997329711908,
#  0.06800005149841315,
#  0.13399992752075196,
#  0.12899992370605418,
#  0.15300001525878892,
#  0.001999839782715007,
#  0.5649999923706055,
#  0.09699994564056391,
#  0.09999977111816438,
#  0.04799990844726576,
#  0.23599997711181642,
#  0.23400003337860098,
#  0.11999996566772442,
#  -0.011000144958495994,
#  0.06800007629394544,
#  1.4490000324249266,
#  0.9690000038146973,
#  0.09199996471405036,
#  0.08999988555908178,
#  0.05699994468688985,
#  0.043000085830688484,
#  0.1519999961853027,
#  0.9809999923706059,
#  0.1310000457763678,
#  0.011000007629394126,
#  0.14999920654296872,
#  0.11699999427795404,
#  0.06299990844726544,
#  0.11799994277954085,
#  0.058000167846680384,
#  0.06399994087219252,
#  0.16299988174438518,
#  0.14200010681152353,
#  -0.17300007629394543,
#  0.13199999618530267,
#  0.07799996471405013,
#  0.14900008201599135,
#  0.13600002861022942,
#  0.1389998836517332,
#  0.09699992752075204,
#  -3.7090009002685562,
#  0.12100000762939445,
#  0.07699999237060506,
#  0.06199995040893569,
#  0.18599995136260983,
#  0.22199986648559555,
#  0.03900003242492667,
#  0.1169999637603758,
#  0.17000041198730464,
#  -0.22500002670288088,
#  0.16300005245208737,
#  0.11299995422363285,
#  0.2619999866485596,
#  0.8890000219345091,
#  0.023000053405761278,
#  0.07000003051757808,
#  0.10300002479553227,
#  -0.012000160217285227,
#  0.09200007057189952,
#  0.02900001049041756,
#  0.6799999656677245,
#  0.12600004959106448,
#  ...]

# %% [markdown]
# 👉 If you are stuck with this question, try `(4) LSTM` and come back to this afterwards.
#
# 🧑🏻‍🏫 Ask a TA if needed. Look at the answer only if you already tried to answer these questions unsuccessfully.
#
# <details>
#     <summary><i>Answer</i></summary>
#
#
# ```python
# def constant_prediction(X, y):
#     errors = []
#     for xx, yy in zip(X, y):
#         last_salary = xx[-1][0]        # Using the 10th salary to predict the 11th salary
#         errors.append(yy - last_salary)
#
#     return errors
# ```
#
# </details>

# %% [markdown]
# 😁 You should notice that your RNN performs a bit better than a baseline model.

# %% [markdown]
# ## (4) 💻 LSTM: Long-Short Term Memory

# %% [markdown]
# ❓ **Questions** ❓
#
# * Write the exact same model, but with a `LSTM` layer instead of a `SimpleRNN` layer
# * Evaluate your performance on the test set

# %%
# YOUR CODE HERE
model = Sequential()
model.add(norm_layer)
model.add(LSTM(units=20, activation='tanh', input_shape=X_train.shape))
model.add(Dense(10, activation="tanh"))
model.add(Dense(1, activation="linear"))

# %%
model.compile(loss='mae', 
              optimizer=RMSprop())

# %%
es = EarlyStopping(patience = 5)
model.fit(X_train, y_train, 
          epochs=100, 
          verbose=1,
          validation_split = 0.2,
          callbacks = [es],
          shuffle = True
         )
# Out:
# Epoch 1/100
# 500/500 [==============================] - 2s 2ms/step - loss: 2.3775 - val_loss: 1.6075
# Epoch 2/100
# 500/500 [==============================] - 1s 1ms/step - loss: 1.2869 - val_loss: 1.0332
# Epoch 3/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.9119 - val_loss: 0.8587
# Epoch 4/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.7358 - val_loss: 0.6944
# Epoch 5/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.6367 - val_loss: 0.6083
# Epoch 6/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.5753 - val_loss: 0.5580
# Epoch 7/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.5292 - val_loss: 0.4984
# Epoch 8/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4939 - val_loss: 0.4649
# Epoch 9/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4651 - val_loss: 0.4267
# Epoch 10/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4436 - val_loss: 0.4081
# Epoch 11/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4245 - val_loss: 0.4007
# Epoch 12/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4083 - val_loss: 0.4022
# Epoch 13/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3949 - val_loss: 0.4042
# Epoch 14/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3821 - val_loss: 0.3885
# Epoch 15/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3735 - val_loss: 0.3721
# Epoch 16/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3644 - val_loss: 0.3981
# Epoch 17/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3556 - val_loss: 0.3545
# Epoch 18/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3501 - val_loss: 0.3297
# Epoch 19/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3440 - val_loss: 0.3341
# Epoch 20/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3384 - val_loss: 0.3282
# Epoch 21/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3330 - val_loss: 0.3416
# Epoch 22/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3285 - val_loss: 0.3184
# Epoch 23/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3246 - val_loss: 0.3024
# Epoch 24/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3202 - val_loss: 0.2992
# Epoch 25/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3169 - val_loss: 0.3138
# Epoch 26/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3142 - val_loss: 0.2991
# Epoch 27/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3110 - val_loss: 0.3041
# Epoch 28/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3082 - val_loss: 0.3622
# Epoch 29/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3063 - val_loss: 0.2962
# Epoch 30/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3038 - val_loss: 0.2985
# Epoch 31/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.3004 - val_loss: 0.3128
# Epoch 32/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2982 - val_loss: 0.2878
# Epoch 33/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2960 - val_loss: 0.2940
# Epoch 34/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2937 - val_loss: 0.3045
# Epoch 35/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2923 - val_loss: 0.2861
# Epoch 36/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2908 - val_loss: 0.3224
# Epoch 37/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2889 - val_loss: 0.2909
# Epoch 38/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2872 - val_loss: 0.3100
# Epoch 39/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2853 - val_loss: 0.2815
# Epoch 40/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2843 - val_loss: 0.2813
# Epoch 41/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2828 - val_loss: 0.2838
# Epoch 42/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2808 - val_loss: 0.2765
# Epoch 43/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2800 - val_loss: 0.2921
# Epoch 44/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2780 - val_loss: 0.2978
# Epoch 45/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2779 - val_loss: 0.2963
# Epoch 46/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2766 - val_loss: 0.3001
# Epoch 47/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2763 - val_loss: 0.2849

# %% [markdown]
# 💪 The LSTM should perform a bit better than the SimpleRNN with a lower MAE.

# %% [markdown]
# 🏁 Congratulations! You know how to train a RNN on sequential data.
#
#
# 💾 Do not forget to git add/commit/push your notebook...
#
# 🚀 ... and move to the next challenge!
#
# ---
#
# <u>Note</u>: The sequences you worked with are totally fake. In case, you need to train and reproduce similar data, you can find below the functions that have been used to simulate such a dataset.

# %% [markdown]
# ## 🛠 (Utils)

# %%
def create_sequences(number):
    X, y = [], []
    
    for i in range(number):
        x_i, y_i = create_individual_sequence(10)
        X.append(x_i)
        y.append(y_i)
        
    return np.array(X), np.array(y)
            
def create_individual_sequence(length):
    company_sizes = []
    nb_persons = []
    salaries = []
    
    
    # Education level
    educ_level = [max(0, int(np.random.normal(10, 2)))]*length
    
    # Company size
    current_size = int(1 + np.random.beta(.4, 4)*500)
    for i in range(length):
        if not np.random.randint(4): # Change 1 out of 3 possibilities 
            current_size = int(max(1, np.random.normal(current_size, 50)))
        company_sizes.append(current_size)
    
    # Number of persons
    nb_iter = np.random.beta(.15, 4)*300
    for i in range(length):
        if not np.random.randint(2): # Change 1 out of 2 possibilities
            R_1 = np.random.beta(0.5, 8)*3
            nb_iter = nb_iter + max(-2, R_1*company_sizes[i] + np.random.randint(-2, 2))
            nb_iter = max(0, nb_iter)
            nb_iter = int(min(company_sizes[i]-1, nb_iter))
        nb_persons.append(nb_iter)
        
    
    # Salary
    salary_iter = max(800, int(np.random.normal(1200, 300)+ 0.05*company_sizes[0] +  np.random.normal(40, 400)))
    salaries.append(salary_iter)
    for i in range(1, length + 1):
        R_1 = np.random.normal(100, 50)
        change_person = nb_persons[i-1] - nb_persons[i-2]
        change_company = max(0, company_sizes[i-1] - company_sizes[i-2])
        salary_iter = salary_iter + 0.05*change_company + change_person*R_1 + np.random.normal(100, 50)
        salary_iter = max(int(salary_iter), 500)
        
        salaries.append(salary_iter)

    y = salaries[-1]/1000
    salaries = [_/1000 for _ in salaries[:-1]]
    
    return np.array([salaries, nb_persons, company_sizes]).T, y

# %%
X, y = create_sequences(25000)

np.save('X', X.astype(np.float32))
np.save('y', y)
